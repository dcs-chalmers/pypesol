# %% [markdown]
# # 3rd SESBC Summer School Exercises
#
# 2026-08-19
#
# Romaric Duvignau, duvignau@chalmers.se
#
# Here below 4 small exercises to get accustomed to the basic functionality of the PyPESOL library.

# %% [markdown]
# ## 0. Data used
#
# For those exercises, we will use prices of 2023.

# %% [markdown]
# ## Exercise 1. When to charge your EV?

# %% [markdown]
# ## Exercise 2. PV and Battery Sizing
#
# ### a. Check Battery Income
#
# ### b.
